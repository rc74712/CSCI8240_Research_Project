# %%
import os
import sys

from pathlib import Path

sys.path.insert(0,str(Path().resolve().parent))

from cfgexplorer import cfg_explore

# %%
cfg_explore(binary='./test.o')
# Out:
# WARNING  | 2023-04-24 17:19:06,480 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: rand
# WARNING  | 2023-04-24 17:19:06,482 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: printf
# WARNING  | 2023-04-24 17:19:06,484 | cle.loader     | For more information about "Symbol was allocated without a known size",see https://docs.angr.io/extending-angr/environment#simdata
# WARNING  | 2023-04-24 17:19:06,490 | angr.analyses.cfg.cfg_fast | "collect_data_references" is deprecated and will be removed soon. Please use "data_references" instead
# WARNING  | 2023-04-24 17:19:06,491 | angr.analyses.cfg.cfg_fast | It is recommended to enable "data_references" if "force_smart_scan" is enabled for best result. Otherwise you may want to disable "force_smart_scan" or enable "force_complete_scan".
# WARNING  | 2023-04-24 17:19:06,492 | angr.analyses.cfg.cfg_fast | You cannot enable "force_smart_scan" and "force_complete_scan" at the same time. I am disabling "force_complete_scan".
#   0% || Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% || Elapsed Time: 0:00:00 Time:  0:00:00
#  * Serving Flask app 'cfgexplorer.explorer'
#  * Debug mode: on
# INFO     | 2023-04-24 17:19:06,620 | werkzeug       | WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO     | 2023-04-24 17:19:06,622 | werkzeug       | Press CTRL+C to quit

# %%
cfg_explore(binary='./test.o', output='./test images/test.svg')
# Out:
# WARNING  | 2023-04-24 17:20:37,237 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: rand
# WARNING  | 2023-04-24 17:20:37,240 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: printf
# WARNING  | 2023-04-24 17:20:37,243 | cle.loader     | For more information about "Symbol was allocated without a known size",see https://docs.angr.io/extending-angr/environment#simdata
# WARNING  | 2023-04-24 17:20:37,254 | angr.analyses.cfg.cfg_fast | "collect_data_references" is deprecated and will be removed soon. Please use "data_references" instead
# WARNING  | 2023-04-24 17:20:37,257 | angr.analyses.cfg.cfg_fast | It is recommended to enable "data_references" if "force_smart_scan" is enabled for best result. Otherwise you may want to disable "force_smart_scan" or enable "force_complete_scan".
# WARNING  | 2023-04-24 17:20:37,259 | angr.analyses.cfg.cfg_fast | You cannot enable "force_smart_scan" and "force_complete_scan" at the same time. I am disabling "force_complete_scan".
#   0% || Elapsed Time: 0:00:00 ETA:  --:--:--
#  60% || Elapsed Time: 0:00:00 ETA:   0:00:00
# 100% || Elapsed Time: 0:00:00 Time:  0:00:00

# %%
from IPython.core.display import SVG
display(SVG('test images/test.svg'))
